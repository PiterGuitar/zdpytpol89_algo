# %% [markdown]
# ### Hash Map

# %% [markdown]
# **Hash map** aka map, hash table, table, dictionary, set

# %% [markdown]
# Funkcja skrótu (ang. Hash function)
#
# Collisions
# $$\text{Load factor} = \frac{\text{\#elements}}{\text{\#buckets}}$$
#
# Collision handling:
# - linear probing
# - separate chaining

# %% [markdown]
# ![image.png](attachment:4bbf8d7b-f4ce-4101-a272-427f6b1da255.png)

# %%
class HashMap:
    def __init__(self, capacity):
        ...
        
    def __len__(self):
        ...

    def __contains__(self, key):
        ...

    def put(self, key, value):
        ...

    def get(self, value):
        ...

    def remove(self, key):
        ...

    def keys(self):
        ...

    def values(self):
        ...

    def items(self):
        ...

    def _hash_function(self):
        ...

# %% [markdown]
# Hash zastosowanie:
# * hashowanie hasła
# * weryfikacja integralności plików/wiadomości
# * identyfikacja plików/danych (git)

# %% [markdown]
# ### Dystrybucja hashy

# %%
import uuid
import matplotlib.pyplot as plt

hash_map = HashMap(100)
for _ in range(100_000):
    hash_map.put(uuid.uuid4(), 'some_value')

# %%
# distribution of the buckets' lenght
X = []
y = []

for idx, bucket in enumerate(hash_map.buckets):
    X.append(idx)
    y.append(len(bucket))

plt.bar(X, y);

# %% [markdown]
# ### Funkcje hashujące

# %% [markdown]
# Wbudowane w pythona funckje hashujące

# %%
import hashlib

# wszystkie dostępne
hashlib.algorithms_available
# Out:
# {'blake2b',
#  'blake2s',
#  'md5',
#  'md5-sha1',
#  'ripemd160',
#  'sha1',
#  'sha224',
#  'sha256',
#  'sha384',
#  'sha3_224',
#  'sha3_256',
#  'sha3_384',
#  'sha3_512',
#  'sha512',
#  'sha512_224',
#  'sha512_256',
#  'shake_128',
#  'shake_256',
#  'sm3'}

# %% [markdown]
# nie wszystkie są możliwe do wykorzystania w każdym systemie. Do wyświetlenia listy algorytmów które są dostępne w Twoim systemie:

# %%
import hashlib

# algorytmy gwarantowane na Twoim systemie
hashlib.algorithms_guaranteed
# Out:
# {'blake2b',
#  'blake2s',
#  'md5',
#  'sha1',
#  'sha224',
#  'sha256',
#  'sha384',
#  'sha3_224',
#  'sha3_256',
#  'sha3_384',
#  'sha3_512',
#  'sha512',
#  'shake_128',
#  'shake_256'}

# %% [markdown]
# Hashing  algorithms
#
# https://www.youtube.com/watch?v=b4b8ktEV4Bg

# %% [markdown]
# SHA - Secure Hashing Algorithm
#
# https://www.youtube.com/watch?v=DMtFhACPnTY
